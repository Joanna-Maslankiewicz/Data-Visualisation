# %% [markdown]
# The list below contains the tennis players who have won the most Grand Slam tournaments. Create a new notebook and then a chart presenting the data from the table. Remember to include the title and description of the chart axis.
#
# Player	Titles
#
# Novak Djokovic	24
#
# Rafael Nadal	22
#
# Roger Federer	20
#
# Pete Sampras	14

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = [24,22,20,14]
chart = pd.Series(data)
chart.index = ['Novak Djokovic','Rafael Nadal','Roger Federer','Pete Sampras']
chart.plot(kind='bar', title="Tennis Players who have won the most Grand Slam tournaments", xlabel='Players', ylabel='Tournaments Won')
# Out:
# <AxesSubplot: title={'center': 'Tennis Players who have won the most Grand Slam tournaments'}, xlabel='Players', ylabel='Tournaments Won'>
